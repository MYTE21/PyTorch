# %% [markdown]
# # Import
#
# * torchsummary: We can see model summary or model architecture using this.
#
# as this is a binary classification problem accuracy is enough for metrics.
# But if it was multiclass problem it's strongly recommended
# to use precision and recall as it will be easy to monitor exact problem of the accuracy.
#
# PyTorch can't detect gpu automatically (unlike tensorflow). So we have to tell PyTorch we have a gpu.

# %%
import platform
import torch
import torch.nn as nn
from torch.optim import Adam
from torch.utils.data import Dataset, DataLoader
from torchsummary import summary
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import  matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
def get_mps() -> str:
    device_name = "mps" if torch.backends.mps.is_available() else "cpu"
    return device_name

# %%
def get_cuda() -> str:
    device_name = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    return device_name

# %%
device = get_mps() if platform.system() == "Darwin" else get_cuda()
print(f"Using device: {device}")
# Out:
# Using device: mps
