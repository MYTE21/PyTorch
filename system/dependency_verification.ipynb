# %% [markdown]
# # 🌋 Dependency Verification (Mac & Windows)
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/MYTE21/AIMO/blob/absol/system/dependency_verification.ipynb)

# %% [markdown]
# ## ⚙️ Imports

# %%
# Libraries: Standard
import logging
import platform

# Libraries: External
import torch

# %% [markdown]
# ## 🌲 Check PyTorch

# %% [markdown]
# <div style = "border: 2px solid #4B0082; padding: 5px 10px; border-radius: 10px;">
# ⚓️ Check the <a href="https://pytorch.org/get-started/locally/">🔗 PyTorch</a> version. ⤵️
# </div>

# %%
print(f"PyTorch version: {torch.__version__}")
# Out:
# PyTorch version: 2.5.1

# %% [markdown]
# <div style = "border: 2px solid #4B0082; padding: 5px 10px; border-radius: 10px;">
# ⚓️ Check PyTorch has access to <a href="https://pytorch.org/get-started/locally/">🔗 MPS (Metal Performance Shader</a>, Apple's GPU architecture). ⤵️
# </div>

# %%
def get_mps() -> str | None:
    try:
        print(f"Is MPS (Metal Performance Shader) built?: {torch.backends.mps.is_built()}")
        print(f"Is MPS available?: {torch.backends.mps.is_available()}")

        device_name = "mps" if torch.backends.mps.is_available() else "cpu"
        return device_name
    except Exception as e:
        logging.error(f"MPS is not available: {e}")

# %% [markdown]
# <div style = "border: 2px solid #4B0082; padding: 5px 10px; border-radius: 10px;">
# ⚓️ Check PyTorch has access to <a href="https://developer.nvidia.com/cuda-zone">🔗 CUDA</a>, Nvidia (Windows). ⤵️
# </div>

# %%
def get_cuda() -> str | None:
    try:
        print(f"Is CUDA available?: {torch.cuda.is_available()}")
        print(f"Available GPU devices: {torch.cuda.device_count()}")
        print(f"Current GPU device: {torch.cuda.current_device()}")
        print(f"Current GPU device name: {torch.cuda.get_device_name(torch.cuda.current_device())}")

        device_name = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        return device_name
    except Exception as e:
        logging.error(f"CUDA is not available: {e}")

# %% [markdown]
# <div style = "border: 2px solid #4B0082; padding: 5px 10px; border-radius: 10px;">
# ⚓️ Set the device. ⤵️
# </div>

# %%
device = get_mps() if platform.system() == "Darwin" else get_cuda()
print(f"Using device: {device}")
# Out:
# Is MPS (Metal Performance Shader) built?: True
# Is MPS available?: True
# Using device: mps

# %% [markdown]
# ## 🔥 Run Data/Models on an (Apple Silicon GPU / Windows Nvidia GPU)

# %% [markdown]
# <div style = "border: 2px solid #4B0082; padding: 5px 10px; border-radius: 10px;">
# ⚓️ Create data and send it to the device. ⤵️
# </div>

# %%
x = torch.rand(size=(3, 4)).to(device)
x
# Out:
# tensor([[0.6446, 0.3775, 0.5172, 0.8218],
#         [0.7655, 0.7569, 0.3868, 0.9832],
#         [0.6400, 0.3438, 0.9586, 0.4447]], device='mps:0')

# %% [markdown]
# <div style = "border: 2px solid #4B0082; padding: 5px 10px; border-radius: 10px;">
# 🎉 Congratulations! The Apple Silicon/Windows device is now running PyTorch.
# </div>
